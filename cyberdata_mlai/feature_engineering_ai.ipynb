# %%
import pandas as pd
import os

from dotenv import load_dotenv

# pandasai imports
from pandasai.llm.openai import OpenAI
from pandasai import SmartDataframe
 
from utils.pcap import pcap_to_dataframe, extract_streams

# %% [markdown]
# # Load Data

# %%
malicious_pcap = "./data/mirai.pcap"
benign_pcap = "./data/benign.pcapng"
malicious_pkl = "./data/mirai.pkl"
benign_pkl = "./data/benign.pkl"

# %%
# finds .env file and loads the vars
load_dotenv()
openai_api_key = os.getenv("OPENAI_API_KEY", "Key not found")
openai_org = os.getenv("OPENAI_ORG", "Organization not found")

# %%
# first time you run this, you should create your own pkl
# for security reasons we do not recommend to use untrusted pkl files
READ_FROM_PKL = True

# %%
if READ_FROM_PKL:
    malicious_df = pd.read_pickle(malicious_pkl)
    benign_df = pd.read_pickle(benign_pkl)
else:
    malicious_df = pcap_to_dataframe(malicious_pcap)
    benign_df = pcap_to_dataframe(benign_pcap)
    # save to pkl since dataframe conversion takes a long time
    malicious_df.to_pickle(malicious_pkl)
    benign_df.to_pickle(benign_pkl)

# %%
# Instantiate a LLM
llm = OpenAI(api_token=openai_api_key)

# %%
# copy the dataframes to a features dataframe while omitting the packets with NaN src/dst ips/ports
malicious_features = malicious_df.dropna(
    subset=["Source IP", "Destination IP", "Source Port", "Destination Port"]
)
benign_features = benign_df.dropna(
    subset=["Source IP", "Destination IP", "Source Port", "Destination Port"]
)

# %% [markdown]
# # Generate Features

# %%
malicious_smart = SmartDataframe(
    df=pd.DataFrame(malicious_features),
    config={"llm": llm, "verbose": True},
    name="Malicious botnet network packet capture.",
    description="A dataframe that is derived from a packet capture of the Mirai botnet network traffic.",
)
malicious_smart_features = malicious_smart.generate_features()
# Out:
# 2024-05-06 18:17:37 [INFO] Question:
# 1. Copy the dataframe to a new variable named df_features.
# 2. Do feature generation.
# 3. Return df_features.
#
# 2024-05-06 18:17:38 [INFO] Running PandasAI with openai LLM...
# 2024-05-06 18:17:38 [INFO] Prompt ID: bbeb7beb-1dbb-4aaa-9568-4009efcd622e
# 2024-05-06 18:17:38 [INFO] Executing Step 0: CacheLookup
# 2024-05-06 18:17:38 [INFO] Using cached response
# 2024-05-06 18:17:38 [INFO] Executing Step 1: PromptGeneration
# 2024-05-06 18:17:38 [INFO] Executing Step 2: CodeGenerator
# 2024-05-06 18:17:38 [INFO] Executing Step 3: CachePopulation
# 2024-05-06 18:17:38 [INFO] Executing Step 4: CodeExecution
# 2024-05-06 18:17:38 [INFO] Saving charts to /home/drx/sandbox/cyberdata-mlai/exports/charts/temp_chart.png
# 2024-05-06 18:17:38 [INFO]
# Code running:
# ```
# df_features = dfs[0].copy()
# df_features['Hour'] = pd.to_datetime(df_features['Timestamp'], unit='ns').dt.hour
# df_features['PacketPayloadRatio'] = df_features['Packet Length'] / df_features['Payload'].str.len()
# result = {'type': 'dataframe', 'value': df_features}
#         ```
# 2024-05-06 18:17:38 [WARNING] Failed to execute code with a correction framework [retry number: 1]
# 2024-05-06 18:17:38 [ERROR] Failed with error: Traceback (most recent call last):
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandasai/pipelines/smart_datalake_chat/code_execution.py", line 46, in execute
#     result = pipeline_context.query_exec_tracker.execute_func(
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandasai/helpers/query_exec_tracker.py", line 128, in execute_func
#     result = function(*args, **kwargs)
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandasai/helpers/code_manager.py", line 207, in execute_code
#     exec(code_to_run, environment)
#   File "<string>", line 2, in <module>
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py", line 1068, in to_datetime
#     values = convert_listlike(arg._values, format)
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py", line 393, in _convert_listlike_datetimes
#     return _to_datetime_with_unit(arg, unit, name, tz, errors)
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py", line 557, in _to_datetime_with_unit
#     arr, tz_parsed = tslib.array_with_unit_to_datetime(arg, unit, errors=errors)
#   File "pandas/_libs/tslib.pyx", line 286, in pandas._libs.tslib.array_with_unit_to_datetime
#   File "pandas/_libs/tslib.pyx", line 683, in pandas._libs.tslib.array_to_datetime
#   File "pandas/_libs/tslib.pyx", line 833, in pandas._libs.tslib._array_to_datetime_object
#   File "pandas/_libs/tslib.pyx", line 655, in pandas._libs.tslib.array_to_datetime
# TypeError: <class 'scapy.utils.EDecimal'> is not convertible to datetime
# . Retrying
# 2024-05-06 18:17:38 [INFO] Using prompt: <dataframe name="Malicious botnet network packet capture." description="A dataframe that is derived from a packet capture of the Mirai botnet network traffic.">
# dfs[0]:154090x8
# Timestamp,Source IP,Destination IP,Source Port,Destination Port,Payload,Packet Length,Protocol
# 1882955139,192.168.2.115,192.168.2.1,2440.0,53.0,"DNS Qry ""b'xmpp.samsun...",83,17.0
# 2650202941,192.168.2.108,52.25.66.250,20532.0,8280.0,Padding...,26,6.0
# 7293619697,192.168.2.108,52.24.43.67,21074.0,80.0,Padding...,26,6.0
# </dataframe>
#
# The user asked the following question:
# Q:
# 1. Copy the dataframe to a new variable named df_features.
# 2. Do feature generation.
# 3. Return df_features.
#
#
# You generated this python code:
# # TODO: import the required dependencies
# import pandas as pd
#
# # Copy the dataframe to a new variable named df_features
# df_features = dfs[0].copy()
#
# # Feature generation
# # Extracting the hour of the day from the Timestamp column
# df_features['Hour'] = pd.to_datetime(df_features['Timestamp'], unit='ns').dt.hour
#
# # Calculating the ratio of Packet Length to Payload Length
# df_features['PacketPayloadRatio'] = df_features['Packet Length'] / df_features['Payload'].str.len()
#
# # Return df_features
# result = {"type": "dataframe", "value": df_features}
#
# It fails with the following error:
# Traceback (most recent call last):
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandasai/pipelines/smart_datalake_chat/code_execution.py", line 46, in execute
#     result = pipeline_context.query_exec_tracker.execute_func(
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandasai/helpers/query_exec_tracker.py", line 128, in execute_func
#     result = function(*args, **kwargs)
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandasai/helpers/code_manager.py", line 207, in execute_code
#     exec(code_to_run, environment)
#   File "<string>", line 2, in <module>
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py", line 1068, in to_datetime
#     values = convert_listlike(arg._values, format)
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py", line 393, in _convert_listlike_datetimes
#     return _to_datetime_with_unit(arg, unit, name, tz, errors)
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py", line 557, in _to_datetime_with_unit
#     arr, tz_parsed = tslib.array_with_unit_to_datetime(arg, unit, errors=errors)
#   File "pandas/_libs/tslib.pyx", line 286, in pandas._libs.tslib.array_with_unit_to_datetime
#   File "pandas/_libs/tslib.pyx", line 683, in pandas._libs.tslib.array_to_datetime
#   File "pandas/_libs/tslib.pyx", line 833, in pandas._libs.tslib._array_to_datetime_object
#   File "pandas/_libs/tslib.pyx", line 655, in pandas._libs.tslib.array_to_datetime
# TypeError: <class 'scapy.utils.EDecimal'> is not convertible to datetime
#
#
# Fix the python code above and return the new python code:
# 2024-05-06 18:17:41 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-06 18:17:41 [INFO] Saving charts to /home/drx/sandbox/cyberdata-mlai/exports/charts/temp_chart.png
# 2024-05-06 18:17:41 [INFO]
# Code running:
# ```
# df_features = dfs[0].copy()
# df_features['Hour'] = pd.to_datetime(df_features['Timestamp'], unit='s').dt.hour
# df_features['PacketPayloadRatio'] = df_features['Packet Length'] / df_features['Payload'].str.len()
# result = {'type': 'dataframe', 'value': df_features}
#         ```
# 2024-05-06 18:17:41 [WARNING] Failed to execute code with a correction framework [retry number: 2]
# 2024-05-06 18:17:41 [ERROR] Failed with error: Traceback (most recent call last):
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandasai/pipelines/smart_datalake_chat/code_execution.py", line 46, in execute
#     result = pipeline_context.query_exec_tracker.execute_func(
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandasai/helpers/query_exec_tracker.py", line 128, in execute_func
#     result = function(*args, **kwargs)
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandasai/helpers/code_manager.py", line 207, in execute_code
#     exec(code_to_run, environment)
#   File "<string>", line 2, in <module>
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py", line 1068, in to_datetime
#     values = convert_listlike(arg._values, format)
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py", line 393, in _convert_listlike_datetimes
#     return _to_datetime_with_unit(arg, unit, name, tz, errors)
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py", line 557, in _to_datetime_with_unit
#     arr, tz_parsed = tslib.array_with_unit_to_datetime(arg, unit, errors=errors)
#   File "pandas/_libs/tslib.pyx", line 382, in pandas._libs.tslib.array_with_unit_to_datetime
# ValueError: unit='s' not valid with non-numerical val='1540446382.933899'
# . Retrying
# 2024-05-06 18:17:41 [INFO] Using prompt: <dataframe name="Malicious botnet network packet capture." description="A dataframe that is derived from a packet capture of the Mirai botnet network traffic.">
# dfs[0]:154090x8
# Timestamp,Source IP,Destination IP,Source Port,Destination Port,Payload,Packet Length,Protocol
# 1882955139,192.168.2.115,192.168.2.1,2440.0,53.0,"DNS Qry ""b'xmpp.samsun...",83,17.0
# 2650202941,192.168.2.108,52.25.66.250,20532.0,8280.0,Padding...,26,6.0
# 7293619697,192.168.2.108,52.24.43.67,21074.0,80.0,Padding...,26,6.0
# </dataframe>
#
# The user asked the following question:
# Q:
# 1. Copy the dataframe to a new variable named df_features.
# 2. Do feature generation.
# 3. Return df_features.
#
#
# You generated this python code:
# # TODO: import the required dependencies
# import pandas as pd
#
# # Copy the dataframe to a new variable named df_features
# df_features = dfs[0].copy()
#
# # Feature generation
# # Extracting the hour of the day from the Timestamp column
# df_features['Hour'] = pd.to_datetime(df_features['Timestamp'], unit='ns').dt.hour
#
# # Calculating the ratio of Packet Length to Payload Length
# df_features['PacketPayloadRatio'] = df_features['Packet Length'] / df_features['Payload'].str.len()
#
# # Return df_features
# result = {"type": "dataframe", "value": df_features}
#
# It fails with the following error:
# Traceback (most recent call last):
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandasai/pipelines/smart_datalake_chat/code_execution.py", line 46, in execute
#     result = pipeline_context.query_exec_tracker.execute_func(
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandasai/helpers/query_exec_tracker.py", line 128, in execute_func
#     result = function(*args, **kwargs)
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandasai/helpers/code_manager.py", line 207, in execute_code
#     exec(code_to_run, environment)
#   File "<string>", line 2, in <module>
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py", line 1068, in to_datetime
#     values = convert_listlike(arg._values, format)
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py", line 393, in _convert_listlike_datetimes
#     return _to_datetime_with_unit(arg, unit, name, tz, errors)
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py", line 557, in _to_datetime_with_unit
#     arr, tz_parsed = tslib.array_with_unit_to_datetime(arg, unit, errors=errors)
#   File "pandas/_libs/tslib.pyx", line 382, in pandas._libs.tslib.array_with_unit_to_datetime
# ValueError: unit='s' not valid with non-numerical val='1540446382.933899'
#
#
# Fix the python code above and return the new python code:
# 2024-05-06 18:17:44 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-06 18:17:44 [INFO] Saving charts to /home/drx/sandbox/cyberdata-mlai/exports/charts/temp_chart.png
# 2024-05-06 18:17:44 [INFO]
# Code running:
# ```
# df_features = dfs[0].copy()
# df_features['Timestamp'] = pd.to_datetime(df_features['Timestamp'])
# df_features['Hour'] = df_features['Timestamp'].dt.hour
# df_features['PacketPayloadRatio'] = df_features['Packet Length'] / df_features['Payload'].str.len()
# result = {'type': 'dataframe', 'value': df_features}
#         ```
# 2024-05-06 18:17:44 [ERROR] Pipeline failed on step 4: <class 'scapy.utils.EDecimal'> is not convertible to datetime

# %%
benign_smart = SmartDataframe(
    df=pd.DataFrame(benign_features),
    config={"llm": llm, "verbose": True},
    name="Benign activity network packet capture.",
    description="A dataframe that is derived from a packet capture of benign network traffic.",
)
benign_smart_features = benign_smart.generate_features()
# Out:
# 2024-05-06 18:17:44 [INFO] Question:
# 1. Copy the dataframe to a new variable named df_features.
# 2. Do feature generation.
# 3. Return df_features.
#
# 2024-05-06 18:17:44 [INFO] Running PandasAI with openai LLM...
# 2024-05-06 18:17:44 [INFO] Prompt ID: caec143a-78a5-4662-847a-a53626ef739b
# 2024-05-06 18:17:44 [INFO] Executing Step 0: CacheLookup
# 2024-05-06 18:17:44 [INFO] Using cached response
# 2024-05-06 18:17:44 [INFO] Executing Step 1: PromptGeneration
# 2024-05-06 18:17:44 [INFO] Executing Step 2: CodeGenerator
# 2024-05-06 18:17:44 [INFO] Executing Step 3: CachePopulation
# 2024-05-06 18:17:44 [INFO] Executing Step 4: CodeExecution
# 2024-05-06 18:17:44 [INFO] Saving charts to /home/drx/sandbox/cyberdata-mlai/exports/charts/temp_chart.png
# 2024-05-06 18:17:44 [INFO]
# Code running:
# ```
# df_features = dfs[0].copy()
# df_features['Hour'] = pd.to_datetime(df_features['Timestamp'], unit='ns').dt.hour
# df_features['PacketPayloadRatio'] = df_features['Packet Length'] / df_features['Payload'].str.len()
# result = {'type': 'dataframe', 'value': df_features}
#         ```
# 2024-05-06 18:17:44 [WARNING] Failed to execute code with a correction framework [retry number: 1]
# 2024-05-06 18:17:44 [ERROR] Failed with error: Traceback (most recent call last):
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandasai/pipelines/smart_datalake_chat/code_execution.py", line 46, in execute
#     result = pipeline_context.query_exec_tracker.execute_func(
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandasai/helpers/query_exec_tracker.py", line 128, in execute_func
#     result = function(*args, **kwargs)
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandasai/helpers/code_manager.py", line 207, in execute_code
#     exec(code_to_run, environment)
#   File "<string>", line 2, in <module>
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py", line 1068, in to_datetime
#     values = convert_listlike(arg._values, format)
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py", line 393, in _convert_listlike_datetimes
#     return _to_datetime_with_unit(arg, unit, name, tz, errors)
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py", line 557, in _to_datetime_with_unit
#     arr, tz_parsed = tslib.array_with_unit_to_datetime(arg, unit, errors=errors)
#   File "pandas/_libs/tslib.pyx", line 286, in pandas._libs.tslib.array_with_unit_to_datetime
#   File "pandas/_libs/tslib.pyx", line 683, in pandas._libs.tslib.array_to_datetime
#   File "pandas/_libs/tslib.pyx", line 833, in pandas._libs.tslib._array_to_datetime_object
#   File "pandas/_libs/tslib.pyx", line 655, in pandas._libs.tslib.array_to_datetime
# TypeError: <class 'scapy.utils.EDecimal'> is not convertible to datetime
# . Retrying
# 2024-05-06 18:17:44 [INFO] Using prompt: <dataframe name="Benign activity network packet capture." description="A dataframe that is derived from a packet capture of benign network traffic.">
# dfs[0]:18615x8
# Timestamp,Source IP,Destination IP,Source Port,Destination Port,Payload,Packet Length,Protocol
# 1116301834,10.0.0.2,224.0.0.2,646.0,646.0,Raw,42,17.0
# 2567469721,10.0.0.1,224.0.0.2,646.0,646.0,Raw,42,17.0
# 1452520993,10.0.0.1,224.0.0.2,646.0,646.0,Raw,42,17.0
# </dataframe>
#
# The user asked the following question:
# Q:
# 1. Copy the dataframe to a new variable named df_features.
# 2. Do feature generation.
# 3. Return df_features.
#
#
# You generated this python code:
# # TODO: import the required dependencies
# import pandas as pd
#
# # Copy the dataframe to a new variable named df_features
# df_features = dfs[0].copy()
#
# # Feature generation
# # Extracting the hour of the day from the Timestamp column
# df_features['Hour'] = pd.to_datetime(df_features['Timestamp'], unit='ns').dt.hour
#
# # Calculating the ratio of Packet Length to Payload Length
# df_features['PacketPayloadRatio'] = df_features['Packet Length'] / df_features['Payload'].str.len()
#
# # Return df_features
# result = {"type": "dataframe", "value": df_features}
#
# It fails with the following error:
# Traceback (most recent call last):
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandasai/pipelines/smart_datalake_chat/code_execution.py", line 46, in execute
#     result = pipeline_context.query_exec_tracker.execute_func(
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandasai/helpers/query_exec_tracker.py", line 128, in execute_func
#     result = function(*args, **kwargs)
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandasai/helpers/code_manager.py", line 207, in execute_code
#     exec(code_to_run, environment)
#   File "<string>", line 2, in <module>
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py", line 1068, in to_datetime
#     values = convert_listlike(arg._values, format)
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py", line 393, in _convert_listlike_datetimes
#     return _to_datetime_with_unit(arg, unit, name, tz, errors)
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py", line 557, in _to_datetime_with_unit
#     arr, tz_parsed = tslib.array_with_unit_to_datetime(arg, unit, errors=errors)
#   File "pandas/_libs/tslib.pyx", line 286, in pandas._libs.tslib.array_with_unit_to_datetime
#   File "pandas/_libs/tslib.pyx", line 683, in pandas._libs.tslib.array_to_datetime
#   File "pandas/_libs/tslib.pyx", line 833, in pandas._libs.tslib._array_to_datetime_object
#   File "pandas/_libs/tslib.pyx", line 655, in pandas._libs.tslib.array_to_datetime
# TypeError: <class 'scapy.utils.EDecimal'> is not convertible to datetime
#
#
# Fix the python code above and return the new python code:
# 2024-05-06 18:17:47 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-06 18:17:47 [INFO] Saving charts to /home/drx/sandbox/cyberdata-mlai/exports/charts/temp_chart.png
# 2024-05-06 18:17:47 [INFO]
# Code running:
# ```
# df_features = dfs[0].copy()
# df_features['Timestamp'] = pd.to_datetime(df_features['Timestamp'])
# df_features['Hour'] = df_features['Timestamp'].dt.hour
# df_features['PacketPayloadRatio'] = df_features['Packet Length'] / df_features['Payload'].str.len()
# result = {'type': 'dataframe', 'value': df_features}
#         ```
# 2024-05-06 18:17:47 [WARNING] Failed to execute code with a correction framework [retry number: 2]
# 2024-05-06 18:17:47 [ERROR] Failed with error: Traceback (most recent call last):
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandasai/pipelines/smart_datalake_chat/code_execution.py", line 46, in execute
#     result = pipeline_context.query_exec_tracker.execute_func(
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandasai/helpers/query_exec_tracker.py", line 128, in execute_func
#     result = function(*args, **kwargs)
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandasai/helpers/code_manager.py", line 207, in execute_code
#     exec(code_to_run, environment)
#   File "<string>", line 2, in <module>
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py", line 1068, in to_datetime
#     values = convert_listlike(arg._values, format)
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py", line 438, in _convert_listlike_datetimes
#     result, tz_parsed = objects_to_datetime64ns(
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandas/core/arrays/datetimes.py", line 2177, in objects_to_datetime64ns
#     result, tz_parsed = tslib.array_to_datetime(
#   File "pandas/_libs/tslib.pyx", line 427, in pandas._libs.tslib.array_to_datetime
#   File "pandas/_libs/tslib.pyx", line 683, in pandas._libs.tslib.array_to_datetime
#   File "pandas/_libs/tslib.pyx", line 833, in pandas._libs.tslib._array_to_datetime_object
#   File "pandas/_libs/tslib.pyx", line 655, in pandas._libs.tslib.array_to_datetime
# TypeError: <class 'scapy.utils.EDecimal'> is not convertible to datetime
# . Retrying
# 2024-05-06 18:17:47 [INFO] Using prompt: <dataframe name="Benign activity network packet capture." description="A dataframe that is derived from a packet capture of benign network traffic.">
# dfs[0]:18615x8
# Timestamp,Source IP,Destination IP,Source Port,Destination Port,Payload,Packet Length,Protocol
# 1116301834,10.0.0.2,224.0.0.2,646.0,646.0,Raw,42,17.0
# 2567469721,10.0.0.1,224.0.0.2,646.0,646.0,Raw,42,17.0
# 1452520993,10.0.0.1,224.0.0.2,646.0,646.0,Raw,42,17.0
# </dataframe>
#
# The user asked the following question:
# Q:
# 1. Copy the dataframe to a new variable named df_features.
# 2. Do feature generation.
# 3. Return df_features.
#
#
# You generated this python code:
# # TODO: import the required dependencies
# import pandas as pd
#
# # Copy the dataframe to a new variable named df_features
# df_features = dfs[0].copy()
#
# # Feature generation
# # Extracting the hour of the day from the Timestamp column
# df_features['Hour'] = pd.to_datetime(df_features['Timestamp'], unit='ns').dt.hour
#
# # Calculating the ratio of Packet Length to Payload Length
# df_features['PacketPayloadRatio'] = df_features['Packet Length'] / df_features['Payload'].str.len()
#
# # Return df_features
# result = {"type": "dataframe", "value": df_features}
#
# It fails with the following error:
# Traceback (most recent call last):
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandasai/pipelines/smart_datalake_chat/code_execution.py", line 46, in execute
#     result = pipeline_context.query_exec_tracker.execute_func(
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandasai/helpers/query_exec_tracker.py", line 128, in execute_func
#     result = function(*args, **kwargs)
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandasai/helpers/code_manager.py", line 207, in execute_code
#     exec(code_to_run, environment)
#   File "<string>", line 2, in <module>
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py", line 1068, in to_datetime
#     values = convert_listlike(arg._values, format)
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py", line 438, in _convert_listlike_datetimes
#     result, tz_parsed = objects_to_datetime64ns(
#   File "/home/drx/sandbox/cyberdata-mlai/.venv/lib/python3.10/site-packages/pandas/core/arrays/datetimes.py", line 2177, in objects_to_datetime64ns
#     result, tz_parsed = tslib.array_to_datetime(
#   File "pandas/_libs/tslib.pyx", line 427, in pandas._libs.tslib.array_to_datetime
#   File "pandas/_libs/tslib.pyx", line 683, in pandas._libs.tslib.array_to_datetime
#   File "pandas/_libs/tslib.pyx", line 833, in pandas._libs.tslib._array_to_datetime_object
#   File "pandas/_libs/tslib.pyx", line 655, in pandas._libs.tslib.array_to_datetime
# TypeError: <class 'scapy.utils.EDecimal'> is not convertible to datetime
#
#
# Fix the python code above and return the new python code:
# 2024-05-06 18:17:49 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-06 18:17:49 [INFO] Saving charts to /home/drx/sandbox/cyberdata-mlai/exports/charts/temp_chart.png
# 2024-05-06 18:17:49 [INFO]
# Code running:
# ```
# df_features = dfs[0].copy()
# df_features['Timestamp'] = df_features['Timestamp'].astype(int)
# df_features['Hour'] = pd.to_datetime(df_features['Timestamp'], unit='ns').dt.hour
# df_features['PacketPayloadRatio'] = df_features['Packet Length'] / df_features['Payload'].str.len()
# result = {'type': 'dataframe', 'value': df_features}
#         ```
# 2024-05-06 18:17:49 [INFO] Executing Step 5: ResultValidation
# 2024-05-06 18:17:49 [INFO] Answer: {'type': 'dataframe', 'value':         Timestamp     Source IP Destination IP  Source Port  Destination Port  \
# 4      1355253962      10.0.0.1      224.0.0.2        646.0             646.0
# 5      1355253962      10.0.0.1      224.0.0.2        646.0             646.0
# 6      1355253962      10.0.0.2      224.0.0.2        646.0             646.0
# 7      1355253962      10.0.0.2      224.0.0.2        646.0             646.0
# 26     1355253966      10.0.0.2      224.0.0.2        646.0             646.0
# ...           ...           ...            ...          ...               ...
# 38585  1671035938  194.247.5.27    194.247.5.1       1812.0           10048.0
# 38586  1671035948   194.247.5.1   194.247.5.27       3860.0            1812.0
# 38587  1671035948  194.247.5.27    194.247.5.1       1812.0            3860.0
# 38588  1671035961   194.247.5.1   194.247.5.27       3373.0            1812.0
# 38589  1671035961  194.247.5.27    194.247.5.1       1812.0            3373.0
#
#       Payload  Packet Length  Protocol  Hour  PacketPayloadRatio
# 4         Raw             42      17.0     0           14.000000
# 5         Raw             42      17.0     0           14.000000
# 6         Raw             42      17.0     0           14.000000
# 7         Raw             42      17.0     0           14.000000
# 26        Raw             42      17.0     0           14.000000
# ...       ...            ...       ...   ...                 ...
# 38585  Radius             40      17.0     0            6.666667
# 38586  Radius            112      17.0     0           18.666667
# 38587  Radius            104      17.0     0           17.333333
# 38588  Radius            120      17.0     0           20.000000
# 38589  Radius            199      17.0     0           33.166667
#
# [18615 rows x 10 columns]}
# 2024-05-06 18:17:49 [INFO] Executed in: 5.522373914718628s
# 2024-05-06 18:17:49 [INFO] Executing Step 6: ResultParsing

# %%
malicious_smart_features
# Out:
# "Unfortunately, I was not able to answer your question, because of the following error:\n\n<class 'scapy.utils.EDecimal'> is not convertible to datetime\n"

# %%
benign_smart_features
# Out:
#         Timestamp     Source IP Destination IP  Source Port  Destination Port  \
# 4      1355253962      10.0.0.1      224.0.0.2        646.0             646.0
# 5      1355253962      10.0.0.1      224.0.0.2        646.0             646.0
# 6      1355253962      10.0.0.2      224.0.0.2        646.0             646.0
# 7      1355253962      10.0.0.2      224.0.0.2        646.0             646.0
# 26     1355253966      10.0.0.2      224.0.0.2        646.0             646.0
# ...           ...           ...            ...          ...               ...
# 38585  1671035938  194.247.5.27    194.247.5.1       1812.0           10048.0
# 38586  1671035948   194.247.5.1   194.247.5.27       3860.0            1812.0
# 38587  1671035948  194.247.5.27    194.247.5.1       1812.0            3860.0
# 38588  1671035961   194.247.5.1   194.247.5.27       3373.0            1812.0
# 38589  1671035961  194.247.5.27    194.247.5.1       1812.0            3373.0
#
#       Payload  Packet Length  Protocol  Hour  PacketPayloadRatio
# 4         Raw             42      17.0     0           14.000000
# 5         Raw             42      17.0     0           14.000000
# 6         Raw             42      17.0     0           14.000000
# 7         Raw             42      17.0     0           14.000000
# 26        Raw             42      17.0     0           14.000000
# ...       ...            ...       ...   ...                 ...
# 38585  Radius             40      17.0     0            6.666667
# 38586  Radius            112      17.0     0           18.666667
# 38587  Radius            104      17.0     0           17.333333
# 38588  Radius            120      17.0     0           20.000000
# 38589  Radius            199      17.0     0           33.166667
#
# [18615 rows x 10 columns]
